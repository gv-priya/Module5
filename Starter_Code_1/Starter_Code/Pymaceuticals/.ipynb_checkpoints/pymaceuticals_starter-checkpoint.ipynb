# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st


# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
merge_df=pd.merge(mouse_metadata, study_results, "outer", "Mouse ID")

# Display the data table for preview
merge_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1893 rows x 8 columns]

# %%
# Checking the number of mice.
Num_mice= merge_df["Mouse ID"].nunique()
Num_mice
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
arrg989 = merge_df.loc[merge_df["Mouse ID"] == 'g989', ["Mouse ID","Timepoint"]]
arrg989.dtypes
# Out:
# Mouse ID     object
# Timepoint     int64
# dtype: object

# %%
# Optional: Get all the data for the duplicate mouse ID. 
DuplicateMouseID= merge_df.loc[merge_df["Mouse ID"] == 'g989', ["Mouse ID", "Timepoint", "Metastatic Sites","Drug Regimen", "Sex", "Age_months", "Weight (g)"]]
DuplicateMouseID
# Out:
#     Mouse ID  Timepoint  Metastatic Sites Drug Regimen     Sex  Age_months  \
# 908     g989          0                 0     Propriva  Female          21
# 909     g989          0                 0     Propriva  Female          21
# 910     g989          5                 0     Propriva  Female          21
# 911     g989          5                 0     Propriva  Female          21
# 912     g989         10                 0     Propriva  Female          21
# 913     g989         10                 0     Propriva  Female          21
# 914     g989         15                 1     Propriva  Female          21
# 915     g989         15                 0     Propriva  Female          21
# 916     g989         20                 1     Propriva  Female          21
# 917     g989         20                 1     Propriva  Female          21
# 918     g989         25                 1     Propriva  Female          21
# 919     g989         30                 1     Propriva  Female          21
# 920     g989         35                 2     Propriva  Female          21
#
#      Weight (g)
# 908          26
# 909          26
# 910          26
# 911          26
# 912          26
# 913          26
# 914          26
# 915          26
# 916          26
# 917          26
# 918          26
# 919          26
# 920          26

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_unique_df = merge_df.drop_duplicates(['Mouse ID'], keep = 'last')
clean_unique_df
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 9        k403     Ramicane    Male          21          16         45
# 19       s185    Capomulin  Female           3          17         45
# 29       x401    Capomulin  Female          16          15         45
# 39       m601    Capomulin    Male          22          17         45
# 49       g791     Ramicane    Male          11          16         45
# ...       ...          ...     ...         ...         ...        ...
# 1859     z314     Stelasyn  Female          21          28          5
# 1862     z435     Propriva  Female          12          26         10
# 1872     z581    Infubinol  Female          24          25         45
# 1882     z795     Naftisol  Female          13          29         45
# 1892     z969     Naftisol    Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 9              22.050126                 1
# 19             23.343598                 1
# 29             28.484033                 0
# 39             28.430964                 1
# 49             29.128472                 1
# ...                  ...               ...
# 1859           45.934712                 0
# 1862           48.710661                 0
# 1872           62.754451                 3
# 1882           65.741070                 3
# 1892           73.867845                 4
#
# [249 rows x 8 columns]

# %%
# Checking the number of mice in the clean DataFrame.
clean_unique_df["Mouse ID"].count()
# Out:
# 249

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.
DRUnique = merge_df.drop_duplicates(["Drug Regimen"], keep = 'first')
DR = list(DRUnique["Drug Regimen"])
Mean = merge_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].mean()
Median= merge_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].median()
Variance = merge_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].var()
Std_Dev = merge_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].std()
Std_Err = merge_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].sem()
Summary_Statistics= pd.DataFrame({"Drug Regimen":DR, "Mean_Tumor Volume":Mean, "Median Tumor Volume":Median, "Tumor Volume Variance":Variance, "Tumor Volume Std.Dev.":Std_Dev, "Tumor Volume Std.Err.":Std_Err})
Summary_Statistics.set_index("Drug Regimen")
# Out:
#               Mean_Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Ramicane              40.675741            41.557809              24.947764
# Capomulin             52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Placebo               55.235638            53.698743              68.553577
# Ceftamin              54.331565            52.509285              66.173479
# Stelasyn              54.033581            52.288934              61.168083
# Zoniferol             52.322552            50.854632              42.351070
# Ketapril              40.216745            40.673236              23.486704
# Propriva              54.233149            52.431737              59.450562
# Naftisol              53.236507            51.818479              48.533355
#
#               Tumor Volume Std.Dev.  Tumor Volume Std.Err.
# Drug Regimen
# Ramicane                   4.994774               0.329346
# Capomulin                  6.268188               0.469821
# Infubinol                  6.567243               0.492236
# Placebo                    8.279709               0.603860
# Ceftamin                   8.134708               0.596466
# Stelasyn                   7.821003               0.581331
# Zoniferol                  6.507770               0.512884
# Ketapril                   4.846308               0.320955
# Propriva                   7.710419               0.573111
# Naftisol                   6.966589               0.516398

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)
# Using the aggregation method, produce the same summary statistics in a single line
stats_aggregate= merge_df.groupby("Drug Regimen").agg({"Tumor Volume (mm3)":['mean','median','var','std','sem']})
stats_aggregate
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
xaxis = DR
yaxis = merge_df.groupby("Drug Regimen")["Timepoint"].count()
Y_axis= yaxis.array
fig, ax = plt.subplots()
bar_container = ax.bar(xaxis, Y_axis)
ax.set(ylabel = "# of Observed Mouse Timepoints", ylim=(100, 250))
ax.bar_label(bar_container, fmt='{:,.0f}')
ax.tick_params(axis= 'x', rotation = 90)

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.

DR_timepoint = merge_df.groupby("Drug Regimen")["Timepoint"].count()
timepoint_DrugRegimen = pd.DataFrame({"#ofObservedTimepointPerdrug":DR_timepoint}, index = DR)
timepoint_DrugRegimen.plot(kind = "bar")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
GenderCountF = clean_unique_df.loc[clean_unique_df["Sex"]== "Female",["Mouse ID"]]
num_of_female_mouse=GenderCountF.count()
GenderCountM = clean_unique_df.loc[clean_unique_df["Sex"] == "Male", ["Mouse ID"]]
num_of_male_mouse=GenderCountM.count()
total_mouseID = clean_unique_df["Mouse ID"].count()
percent_female = round((num_of_female_mouse/total_mouseID ) *100, 2)
F_percent= pd.Series(percent_female)
percent_male = round((num_of_male_mouse/total_mouseID ) *100, 2)
M_percent = pd.Series(percent_male)
Gendercount= pd.DataFrame({'Gender':["Female", "Male"],'value':[F_percent.iloc[0], M_percent.iloc[0]]}, index =[0, 1])
fig, ax = plt.subplots()
ax.pie(Gendercount['value'], labels = Gendercount['Gender'], autopct= '%1.1f%%')
ax.set_ylabel("Sex", size = 10)
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
Gendercount= pd.DataFrame({'Gender':["Male", "Female"],'value':[M_percent.iloc[0], F_percent.iloc[0]]}, index =[0, 1])
fig, ax = plt.subplots()
ax.pie(Gendercount['value'], labels = Gendercount['Gender'], autopct= '%1.1f%%')
ax.set_ylabel("Sex", size = 10)
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
max_tumor= merge_df.groupby("Mouse ID")["Timepoint"].max()
max_tumor=max_tumor.reset_index()
max_tumor
#maxtimepoint_uniquemouseid=pd.merge(max_tumor, clean_unique_df,'outer', 'Mouse ID')
#maxtimepoint_uniquemouseid= maxtimepoint_uniquemouseid.rename({"Timepoint_y":"max Timepoint"})
#maxtimepoint_uniquemouseid.drop("Timepoint_y")
# Out:
#     Mouse ID  Timepoint
# 0       a203         45
# 1       a251         45
# 2       a262         45
# 3       a275         45
# 4       a366         30
# ..       ...        ...
# 244     z435         10
# 245     z578         45
# 246     z581         45
# 247     z795         45
# 248     z969         45
#
# [249 rows x 2 columns]

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
Capomulin_Tumorvolume = merge_df.loc[merge_df["Drug Regimen"]== "Capomulin", ["Drug Regimen","Tumor Volume (mm3)", "Mouse ID", "Timepoint","Weight (g)","Age_months", "Sex", "Metastatic Sites"]]
Capomulin_sorted_mouseid=Capomulin_Tumorvolume.sort_values("Mouse ID")
finalTumorvol_Capomulin=Capomulin_sorted_mouseid.drop_duplicates("Mouse ID", keep = 'first')

Ramicane_Tumorvolume = merge_df.loc[merge_df["Drug Regimen"]== "Ramicane", ["Drug Regimen","Tumor Volume (mm3)", "Mouse ID", "Timepoint","Weight (g)","Age_months", "Sex", "Metastatic Sites"]]
Ramicane_sorted_mouseid = Ramicane_Tumorvolume.sort_values("Mouse ID")
finalTumorvol_Ramicane= Ramicane_sorted_mouseid.drop_duplicates("Mouse ID", keep = 'first')

Infubinol_Tumorvolume = merge_df.loc[merge_df["Drug Regimen"]== "Infubinol", ["Drug Regimen","Tumor Volume (mm3)", "Mouse ID", "Timepoint","Weight (g)","Age_months", "Sex", "Metastatic Sites"]]
Infubinol_sorted_mouseid = Infubinol_Tumorvolume.sort_values("Mouse ID")
finalTumorvol_Infubinol= Infubinol_sorted_mouseid.drop_duplicates("Mouse ID", keep = 'first')

Ceftamin_Tumorvolume = merge_df.loc[merge_df["Drug Regimen"]== "Ceftamin", ["Drug Regimen","Tumor Volume (mm3)", "Mouse ID", "Timepoint","Weight (g)","Age_months", "Sex", "Metastatic Sites"]]
Ceftamin_sorted_mouseid = Ceftamin_Tumorvolume.sort_values("Mouse ID")
finalTumorvol_Ceftamin= Ceftamin_sorted_mouseid.drop_duplicates("Mouse ID", keep = 'first')
# Start by getting the last (greatest) timepoint for each mouse
# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
finalTumorvol_Capomulin
# Out:
#      Drug Regimen  Tumor Volume (mm3) Mouse ID  Timepoint  Weight (g)  \
# 309     Capomulin           38.982878     b128         45          22
# 292     Capomulin           41.999228     b742         10          21
# 60      Capomulin           45.000000     f966          0          17
# 244     Capomulin           37.074024     g288         45          19
# 351     Capomulin           45.000000     g316          0          22
# 431     Capomulin           45.000000     i557          0          24
# 197     Capomulin           43.421014     i738         10          20
# 328     Capomulin           45.000000     j119          0          23
# 313     Capomulin           43.312654     j246         15          21
# 379     Capomulin           40.770813     l509         40          21
# 282     Capomulin           38.846876     l897         45          19
# 30      Capomulin           45.000000     m601          0          17
# 143     Capomulin           32.947615     m957         40          19
# 1452    Capomulin           45.000000     r157          0          25
# 134     Capomulin           32.377357     r554         45          17
# 384     Capomulin           47.373423     r944         15          25
# 10      Capomulin           45.000000     s185          0          17
# 364     Capomulin           41.845235     s710         15          23
# 155     Capomulin           45.000000     t565          0          17
# 100     Capomulin           35.503616     u364         25          17
# 344     Capomulin           40.457989     v923         15          21
# 339     Capomulin           39.202129     w150          5          23
# 224     Capomulin           36.041047     w914         45          21
# 29      Capomulin           28.484033     x401         45          15
# 124     Capomulin           31.896238     y793         45          17
#
#       Age_months     Sex  Metastatic Sites
# 309            9  Female                 2
# 292            7    Male                 0
# 60            16    Male                 0
# 244            3    Male                 1
# 351           22  Female                 0
# 431            1  Female                 0
# 197           23  Female                 0
# 328            7  Female                 0
# 313           21  Female                 0
# 379           17    Male                 2
# 282           17    Male                 1
# 30            22    Male                 0
# 143            3  Female                 1
# 1452          22    Male                 0
# 134            8  Female                 3
# 384           12    Male                 0
# 10             3  Female                 0
# 364            1  Female                 0
# 155           20  Female                 0
# 100           18    Male                 2
# 344           19  Female                 0
# 339           23    Male                 0
# 224           24    Male                 2
# 29            16  Female                 0
# 124           17    Male                 2

# %%
# Put treatments into a list for for loop (and later for plot labels)
list_treatments= ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
# Create empty list to fill with tumor vol data (for plotting)
tumorvolume_data = []
# Calculate the IQR and quantitatively determine if there are any potential outliers. 
Q1=finalTumorvol_Capomulin["Tumor Volume (mm3)"].quantile(0.25)
Q3 = finalTumorvol_Capomulin["Tumor Volume (mm3)"].quantile(0.75)
iqr = Q3 - Q1
lowerlimit = round(Q1 - 1.5 *round(iqr, 2), 2)
upperlimit = round(Q3 + 1.5 *round(iqr,2), 2)
#finding median to find the middle tumor volume in the capomulin drug regimen finalTumorvol_Capomulin 
median = finalTumorvol_Capomulin["Tumor Volume (mm3)"].median()


#print(f"lowerlimit for capomulin = {lowerlimit}, upperlimit for capomulin = {upperlimit}, iqr_capomulin = {round(iqr, 2)}, median={round(median,2)}")

#q_finalTumorvol_Ramicane = finalTumorvol_Ramicane.groupby("Mouse ID")["Tumor Volume (mm3)"].quantile([0.1,0.5,0.9])
#qfinalTumorvol_Ramicane_lower = finalTumorvol_Ramicane.quantile([0.1,0.5,0.9], interpolation = 'lower')
#qfinalTumorvol_Ramicane_higher = finalTumorvol_Ramicane.quantile([0.1,0.5,0.9], interpolation = 'higher')
#q_finalTumorvol_Ramicane

#q_finalTumorvol_Infubinol = finalTumorvol_Infubinol.groupby("Mouse ID")["Tumor Volume (mm3)"].quantile([0.1,0.5,0.9])
#qfinalTumorvol_Infubinol_lower = finalTumorvol_Infubinol.quantile([0.1,0.5,0.9], interpolation = 'lower')
#qfinalTumorvol_Infubinol_higher = finalTumorvol_Infubinol.quantile([0.1,0.5,0.9], interpolation = 'higher')
#q_finalTumorvol_Infubinol
#q_finalTumorvol_Ceftamin = finalTumorvol_Ceftamin.groupby("Mouse ID")["Tumor Volume (mm3)"].quantile([0.1,0.5,0.9])
#qfinalTumorvol_Ceftamin_lower = finalTumorvol_Ceftamin.quantile([0.1,0.5,0.9], interpolation = 'lower')
#qfinalTumorvol_Ceftamin_higher = finalTumorvol_Ceftamin.quantile([0.1,0.5,0.9], interpolation = 'higher')
#q_finalTumorvol_Ceftamin
    # Locate the rows which contain mice on each drug and get the tumor volumes

    
    # add subset 
#q_capomulinTumorvol_arr
#q_capomulinTumorvol 


    # Determine outliers using upper and lower bounds

#Q3.values().subtract(Q1.values(), fill)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
#capomulin_mouse= merge_df.loc[merge_df["Mouse ID"] == 'I509', ["Mouse ID", "Timepoint", "Drug Regimen", "Tumor Volume (mm3)", "Age_months", "Weight (g)"]]
capomulin_mouse = merge_df.loc[merge_df['Mouse ID'] == 'I509', ["Tumor Volume (mm3)","Drug Regimen", "Weight (g)"]]
capomulin_mouse
# Out:
# Empty DataFrame
# Columns: [Tumor Volume (mm3), Drug Regimen, Weight (g)]
# Index: []

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
